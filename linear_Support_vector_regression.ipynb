# %% [markdown]
# <a href="https://colab.research.google.com/github/prerak2323/MACHINE-LEARNING/blob/Linear-Support-Vector-Regression/linear_Support_vector_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np
df=pd.read_csv('bangalore house price prediction OHE-data.csv')
df
# Out:
#       bath  balcony   price  total_sqft_int  bhk  price_per_sqft  \
# 0      3.0      2.0  150.00          1672.0    3     8971.291866
# 1      3.0      3.0  149.00          1750.0    3     8514.285714
# 2      3.0      2.0  150.00          1750.0    3     8571.428571
# 3      2.0      2.0   40.00          1250.0    2     3200.000000
# 4      2.0      2.0   83.00          1200.0    2     6916.666667
# ...    ...      ...     ...             ...  ...             ...
# 7115   3.0      2.0  325.00          2900.0    3    11206.896552
# 7116   3.0      1.0   84.83          1780.0    3     4765.730337
# 7117   2.0      1.0   48.00           880.0    2     5454.545455
# 7118   2.0      1.0   55.00          1000.0    2     5500.000000
# 7119   2.0      1.0   78.00          1400.0    3     5571.428571
#
#       area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                                 1                        0
# ...

# %%
#splitting data
X=df.drop('price',axis=1)
y=df['price']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=50)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(X_train)
X_train=sc.transform(X_train)
X_test=sc.transform(X_test)

# %%
#support vector regression
from sklearn.svm import SVR

# %%
svr_rbf=SVR(kernel='poly',degree=2)
svr_rbf.fit(X_train,y_train)
svr_rbf.score(X_test,y_test)
# Out:
# 0.0984679796493837

# %%
#using linear kernel
svr_lin=SVR(kernel='linear')
svr_lin.fit(X_train,y_train)
svr_lin.score(X_test,y_test)
#best accuracy
# Out:
# 0.7040462927032233

# %%
#using linear kernel
svr_poly=SVR(kernel='poly',degree=2)
svr_poly.fit(X_train,y_train)
svr_poly.score(X_test,y_test)
# Out:
# 0.0984679796493837
